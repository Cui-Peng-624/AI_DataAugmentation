# %%
from 整合版本1014 import main

# %%
import re

def extract_categories(filename):
    # 使用正则表达式匹配文件名格式
    match = re.match(r'(\d+-.+?) - (.+)', filename)
    if match:
        main_category = match.group(1).strip()
        sub_category = match.group(2).strip()
        return main_category, sub_category
    else:
        return None, None

# %%
# 示例调用
if __name__ == "__main__":
    file_names = ["1-网络与通信 - 蜂窝通信模块 (1)", "1-网络与通信 - 宽带网络基础结构 (1)", "1-网络与通信 - 网络与通信系统 (1)", "1-网络与通信 - 物联网各层级价值 (1)", "1-网络与通信 - OFDM跳频技术研究 (1)", "1-网络与通信 - QoS（服务质量）技术研究 (1)"] # 不需要带“.csv”后缀

    for file_name in file_names:
        main_category, sub_category = extract_categories(file_name)
        file_path = f"筛选出指定行之后的数据集/{main_category}/{file_name}.csv"
        save_path = f"1029扩充后的数据集/{main_category}/{file_name}_expanded.csv"
        save_invalid_path = f"invalid_outputs/{main_category}/{sub_category}.txt"

        num_entries = 20
        custom_requirements = ""
        required_total_rows = 20000
        # 执行主流程
        main(file_path, save_path, main_category, sub_category, num_entries, custom_requirements, required_total_rows, save_invalid_path)
# Out:
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13919
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13935
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13953
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13970
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13987
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14005
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14023
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14040
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14057
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14074
# 执行内存清理 - 批次 10
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14091
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14108
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14125
# Generated invalid data. Saved to 'invalid_outputs/1-网络与通信/蜂窝通信模块 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/1-网络与通信/蜂窝通信模块 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14142
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14159
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14176
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14194
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14211
# 执行内存清理 - 批次 20
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14229
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14246
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14263
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14279
# Generated invalid data. Saved to 'invalid_outputs/1-网络与通信/蜂窝通信模块 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/1-网络与通信/蜂窝通信模块 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14297
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14314
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14331
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14349
# 执行内存清理 - 批次 30
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14367
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14385
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14403
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14420
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14438
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14455
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14472
# Generated invalid data. Saved to 'invalid_outputs/1-网络与通信/蜂窝通信模块 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14488
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14505
# 执行内存清理 - 批次 40
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14522
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14540
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14557
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14574
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14591
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14608
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14625
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14642
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14660
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14677
# 执行内存清理 - 批次 50
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14694
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14711
# Generated invalid data. Saved to 'invalid_outputs/1-网络与通信/蜂窝通信模块 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14728
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14744
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14762
# Generated invalid data. Saved to 'invalid_outputs/1-网络与通信/蜂窝通信模块 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14780
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14798
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14815
# 执行内存清理 - 批次 60
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14833
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14850
# Generated invalid data. Saved to 'invalid_outputs/1-网络与通信/蜂窝通信模块 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14867
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14884
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14901
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14920
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14937
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14954
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14970
# 执行内存清理 - 批次 70
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14986
# Generated invalid data. Saved to 'invalid_outputs/1-网络与通信/蜂窝通信模块 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15003
# Generated valid data.
# 已生成数据并追加到文件。当前总行数