# %%
from 整合版本1014 import main

# %%
import re

def extract_categories(filename):
    # 使用正则表达式匹配文件名格式
    match = re.match(r'(\d+-.+?) - (.+)', filename)
    if match:
        main_category = match.group(1).strip()
        sub_category = match.group(2).strip()
        return main_category, sub_category
    else:
        return None, None

# %%
# 示例调用
if __name__ == "__main__":
    file_names = ["14-安全节能环保 - 企业业务考核体系设计", "14-安全节能环保 - 应急能力评估体系"] # 不需要带“.csv”后缀

    for file_name in file_names:
        main_category, sub_category = extract_categories(file_name)
        file_path = f"原始数据集/{main_category}/{file_name}.csv"
        save_path = f"扩充后的数据集/{main_category}/{file_name}_expanded.csv"
        save_invalid_path = f"invalid_outputs/{main_category}/{sub_category}.txt"

        num_entries = 10
        custom_requirements = "为扩大数据量，避免重复，面料请分为一个一个去说"
        required_total_rows = 400
        # 执行主流程
        main(file_path, save_path, main_category, sub_category, num_entries, custom_requirements, required_total_rows, save_invalid_path)
# Out:
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 13，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 22，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 31，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 41，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 50，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 59，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 68，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 78，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 87，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 96，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 105，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 114，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 123，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 132，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 141，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 150，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 159，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 168，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 177，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 187，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 196，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 205，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 215，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 224，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 234，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 243，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 252，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 261，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 270，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 279，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 288，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 297，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 306，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 316，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 325，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 334，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 343，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 352，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 361，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 370，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 379，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 388，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 397，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 企业业务考核体系设计_expanded.csv。当前总行数为 406，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 12，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 21，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 30，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 39，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 48，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 57，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 66，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 75，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 84，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 93，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 102，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 111，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 120，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 129，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 138，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 147，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 156，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 165，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 174，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 183，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 192，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 201，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 210，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 219，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 228，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 237，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 246，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 255，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 264，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 273，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 282，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 291，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 300，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 309，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 318，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 327，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 336，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 345，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 354，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 363，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 373，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 382，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 391，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/14-安全节能环保/14-安全节能环保 - 应急能力评估体系_expanded.csv。当前总行数为 400，继续生成数据...
