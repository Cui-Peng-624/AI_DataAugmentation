# %%
from 整合版本1014 import main

# %%
import re

def extract_categories(filename):
    # 使用正则表达式匹配文件名格式
    match = re.match(r'(\d+-.+?) - (.+)', filename)
    if match:
        main_category = match.group(1).strip()
        sub_category = match.group(2).strip()
        return main_category, sub_category
    else:
        return None, None

# %%
# 示例调用
if __name__ == "__main__":
    file_names = ["4-智能终端 - 家庭智能终端基本信息 (1)", "4-智能终端 - 零部件信息 (1)", "4-智能终端 - 适老化智能终端基本信息 (1)", "4-智能终端 - 移动芯片 (1)", "4-智能终端 - 终端载体情况 (1)"] # 不需要带“.csv”后缀

    for file_name in file_names:
        main_category, sub_category = extract_categories(file_name)
        file_path = f"筛选出指定行之后的数据集/{main_category}/{file_name}.csv"
        save_path = f"1029扩充后的数据集/{main_category}/{file_name}_expanded.csv"
        save_invalid_path = f"invalid_outputs/{main_category}/{sub_category}.txt"

        num_entries = 20
        custom_requirements = ""
        required_total_rows = 20000

        # 执行主流程
        main(file_path, save_path, main_category, sub_category, num_entries, custom_requirements, required_total_rows, save_invalid_path)
# Out:
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：7903
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：7917
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：7931
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：7944
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：7957
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：7971
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：7985
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：7999
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8014
# Generated invalid data. Saved to 'invalid_outputs/4-智能终端/家庭智能终端基本信息 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8028
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8043
# Generated invalid data. Saved to 'invalid_outputs/4-智能终端/家庭智能终端基本信息 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8056
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8071
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8085
# Generated invalid data. Saved to 'invalid_outputs/4-智能终端/家庭智能终端基本信息 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8098
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8112
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8127
# 执行内存清理 - 批次 20
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8142
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8156
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8169
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8182
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8195
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8209
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8222
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8236
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8250
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8264
# 执行内存清理 - 批次 30
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8277
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8292
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8307
# Generated invalid data. Saved to 'invalid_outputs/4-智能终端/家庭智能终端基本信息 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8320
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8333
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8347
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8360
# Generated invalid data. Saved to 'invalid_outputs/4-智能终端/家庭智能终端基本信息 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8374
# 执行内存清理 - 批次 40
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8388
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8402
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8417
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8431
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8446
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8461
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8477
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8492
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8506
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8521
# 执行内存清理 - 批次 50
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8535
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8550
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8565
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8579
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8591
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8603
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8617
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8632
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8645
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8660
# 执行内存清理 - 批次 60
# Generated invalid data. Saved to 'invalid_outputs/4-智能终端/家庭智能终端基本信息 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8674
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8686
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8700
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8714
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8728
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8742
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8756
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8770
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8784
# 执行内存清理 - 批次 70
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8800
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8814
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8828
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8841
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8854
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8867
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8879
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8893
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8907
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8922
# 执行内存清理 - 批次 80
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8936
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8949
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8964
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8979
# Generated invalid data. Saved to 'invalid_outputs/4-智能终端/家庭智能终端基本信息 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：8994
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9009
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9022
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9037
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9051
# 执行内存清理 - 批次 90
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9067
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9082
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9096
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9111
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9125
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9139
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9153
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9167
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9182
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9196
# 执行内存清理 - 批次 100
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9209
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9223
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9237
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9252
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9266
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9279
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9293
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9309
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9322
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9337
# 执行内存清理 - 批次 110
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9352
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9367
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9381
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9395
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9410
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9424
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9438
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9452
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9466
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9480
# 执行内存清理 - 批次 120
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9494
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9507
# Generated invalid data. Saved to 'invalid_outputs/4-智能终端/家庭智能终端基本信息 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9521
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9536
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9550
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9564
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：9578
