# %%
from 整合版本1014 import main

# %%
import re

def extract_categories(filename):
    # 使用正则表达式匹配文件名格式
    match = re.match(r'(\d+-.+?) - (.+)', filename)
    if match:
        main_category = match.group(1).strip()
        sub_category = match.group(2).strip()
        return main_category, sub_category
    else:
        return None, None

# %%
# 示例调用
if __name__ == "__main__":
    file_names = ["3-超高清视频显示 - 8K超高清视频相关技术 (1)", "3-超高清视频显示 - 软件系统 (1)", "3-超高清视频显示 - 数字视频标准 (1)", "3-超高清视频显示 - 系统相关参数 (1)", "3-超高清视频显示 - 硬件系统 (1)", "3-超高清视频显示 - LED液晶显示屏相关技术 (1)"]  # 不需要带“.csv”后缀

    for file_name in file_names:
        main_category, sub_category = extract_categories(file_name)
        file_path = f"筛选出指定行之后的数据集/{main_category}/{file_name}.csv"
        save_path = f"1029扩充后的数据集/{main_category}/{file_name}_expanded.csv"
        save_invalid_path = f"invalid_outputs/{main_category}/{sub_category}.txt"

        num_entries = 20
        custom_requirements = ""
        required_total_rows = 1000

        # 执行主流程
        main(file_path, save_path, main_category, sub_category, num_entries, custom_requirements, required_total_rows, save_invalid_path)
# Out:
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 28，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 46，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 64，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 82，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 100，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 118，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 135，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 153，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 171，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 190，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 209，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 227，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 245，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 264，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 281，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 299，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 317，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 334，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 351，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 369，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 387，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 407，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 425，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 443，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 462，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 479，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 497，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 516，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 534，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 552，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 571，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 588，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 607，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 625，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 1029扩充后的数据集/3-超高清视频显示/3-超高清视频显示 - 8K超高清视频相关技术 (1)_expanded.csv。当前总行数为 642，继续生成数据...
# 发生未预期的错误：<!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.zetatechs.com | 504: Gateway time-out</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Gateway time-out</span>
#               <span class="code-label">Error code 504</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2024-11-05 06:28:09 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Tokyo</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.zetatechs.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>The web server reported a gateway time-out error.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                     <p class="mb-6">Please try again in a few minutes.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">8ddac6bc2ed47376</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">212.107.30.195</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>。跳过本次生成，继续下一次。
# 发生未预期的错误：<!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.zetatechs.com | 504: Gateway time-out</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Gateway time-out</span>
#               <span class="code-label">Error code 504</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2024-11-05 06:31:12 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Tokyo</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.zetatechs.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>The web server reported a gateway time-out error.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                     <p class="mb-6">Please try again in a few minutes.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">8ddacb31bf917376</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">212.107.30.195</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>。跳过本次生成，继续下一次。
# 发生未预期的错误：<!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.zetatechs.com | 504: Gateway time-out</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Gateway time-out</span>
#               <span class="code-label">Error code 504</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2024-11-05 06:34:15 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Tokyo</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.zetatechs.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>The web server reported a gateway time-out error.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                     <p class="mb-6">Please try again in a few minutes.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">8ddacfa6eeb97376</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">212.107.30.195</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>。跳过本次生成，继续下一次。
# 发生未预期的错误：<!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.zetatechs.com | 504: Gateway time-out</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Gateway time-out</span>
#               <span class="code-label">Error code 504</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2024-11-05 06:37:16 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Tokyo</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.zetatechs.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>The web server reported a gateway time-out error.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                     <p class="mb-6">Please try again in a few minutes.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">8ddad41d2b077376</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">212.107.30.195</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>。跳过本次生成，继续下一次。
# 发生未预期的错误：<!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.zetatechs.com | 504: Gateway time-out</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Gateway time-out</span>
#               <span class="code-label">Error code 504</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2024-11-05 06:40:19 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Tokyo</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.zetatechs.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>The web server reported a gateway time-out error.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                     <p class="mb-6">Please try again in a few minutes.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">8ddad893ddfd7376</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">212.107.30.195</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>。跳过本次生成，继续下一次。
# 发生未预期的错误：<!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.zetatechs.com | 504: Gateway time-out</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Gateway time-out</span>
#               <span class="code-label">Error code 504</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2024-11-05 06:43:22 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Tokyo</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.zetatechs.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>The web server reported a gateway time-out error.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                     <p class="mb-6">Please try again in a few minutes.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">8ddadd07ed9a7376</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">212.107.30.195</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>。跳过本次生成，继续下一次。
# 发生未预期的错误：<!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.zetatechs.com | 504: Gateway time-out</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Gateway time-out</span>
#               <span class="code-label">Error code 504</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2024-11-05 06:46:24 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Tokyo</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.zetatechs.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>The web server reported a gateway time-out error.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                     <p class="mb-6">Please try again in a few minutes.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">8ddae1791de67376</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">212.107.30.195</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_504&utm_campaign=api.zetatechs.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>。跳过本次生成，继续下一次。
