# %%
from 整合版本1014 import main

# %%
import re

def extract_categories(filename):
    # 使用正则表达式匹配文件名格式
    match = re.match(r'(\d+-.+?) - (.+)', filename)
    if match:
        main_category = match.group(1).strip()
        sub_category = match.group(2).strip()
        return main_category, sub_category
    else:
        return None, None

# %%
# 示例调用
if __name__ == "__main__":
    file_names = ["7-数字创意 - 动画主题词及评论"] # 不需要带“.csv”后缀

    for file_name in file_names:
        main_category, sub_category = extract_categories(file_name)
        file_path = f"原始数据集/{main_category}/{file_name}.csv"
        save_path = f"扩充后的数据集/{main_category}/{file_name}_expanded.csv"
        save_invalid_path = f"invalid_outputs/{main_category}/{sub_category}.txt"

        num_entries = 10
        custom_requirements = ""
        required_total_rows = 500

        # 执行主流程
        main(file_path, save_path, main_category, sub_category, num_entries, custom_requirements, required_total_rows, save_invalid_path)
# Out:
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 28，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 38，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 48，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 58，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 68，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 78，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 88，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 98，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 108，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 118，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 128，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 138，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 148，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 158，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 168，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 178，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 188，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 198，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 208，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 218，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 228，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 238，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 248，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 258，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 268，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 278，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 288，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 298，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 308，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 318，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 328，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 338，继续生成数据...
# Generated invalid data. Saved to 'invalid_outputs/7-数字创意/动画主题词及评论.txt' for manual processing.
# 本次生成的数据不符合自定义的结构要求，使用json mode提取数据。扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 348，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 358，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 368，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 378，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 388，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 398，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 408，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 418，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 428，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 438，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 448，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 458，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 468，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 478，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 488，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 498，继续生成数据...
# Generated valid data.
# 扩展后的数据已追加到 扩充后的数据集/7-数字创意/7-数字创意 - 动画主题词及评论_expanded.csv。当前总行数为 508，继续生成数据...
