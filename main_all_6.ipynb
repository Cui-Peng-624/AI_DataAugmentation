# %%
from 整合版本1014 import main

# %%
import re

def extract_categories(filename):
    # 使用正则表达式匹配文件名格式
    match = re.match(r'(\d+-.+?) - (.+)', filename)
    if match:
        main_category = match.group(1).strip()
        sub_category = match.group(2).strip()
        return main_category, sub_category
    else:
        return None, None

# %%
# 示例调用
if __name__ == "__main__":
    file_names = ["6-软件与信息服务 - 软件外包及产业基地情况 (1)", "6-软件与信息服务 - 软件与信息技术服务商主要核心技术 (1)", "6-软件与信息服务 - 软件与信息技术服务商咨询与解决方案案例 (1)", "6-软件与信息服务 - 数字内容供应 (1)", "6-软件与信息服务 - MES应用信息 (1)"] # 不需要带“.csv”后缀

    for file_name in file_names:
        main_category, sub_category = extract_categories(file_name)
        file_path = f"筛选出指定行之后的数据集/{main_category}/{file_name}.csv"
        save_path = f"1029扩充后的数据集/{main_category}/{file_name}_expanded.csv"
        save_invalid_path = f"invalid_outputs/{main_category}/{sub_category}.txt"

        num_entries = 20
        custom_requirements = ""
        required_total_rows = 20000

        # 执行主流程
        main(file_path, save_path, main_category, sub_category, num_entries, custom_requirements, required_total_rows, save_invalid_path)
# Out:
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：11955
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：11972
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：11987
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12003
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12019
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12036
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12053
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12071
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12088
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12104
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12121
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12137
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12153
# 执行内存清理 - 批次 20
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12170
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12187
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12204
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12222
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12238
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12254
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12271
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12287
# 执行内存清理 - 批次 30
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12303
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12320
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12336
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12352
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12367
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12383
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12400
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12417
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12434
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12451
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12468
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12485
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12502
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12518
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12535
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12552
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12568
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12584
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12601
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12618
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12635
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12651
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12667
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12683
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12701
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12718
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12735
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12752
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12769
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12785
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12801
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12818
# 执行内存清理 - 批次 80
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12834
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12849
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12866
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12883
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12900
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12917
# 执行内存清理 - 批次 90
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12935
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12952
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12969
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：12985
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13001
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13016
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13031
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13047
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13064
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13080
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13096
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13113
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13129
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13145
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13162
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13178
# 执行内存清理 - 批次 110
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13195
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13211
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13228
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13245
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13263
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13280
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13295
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13311
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13327
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13342
# 执行内存清理 - 批次 120
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13358
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13375
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13392
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13409
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13426
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13443
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13460
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13476
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13493
# 执行内存清理 - 批次 130
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13509
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13526
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13542
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13558
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13574
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13591
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13607
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13624
# 执行内存清理 - 批次 140
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13641
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13657
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13673
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13689
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13705
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13722
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13739
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13756
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13772
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13788
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13806
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13822
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13839
# 执行内存清理 - 批次 160
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13855
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13872
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13887
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13903
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13920
# 执行内存清理 - 批次 170
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13936
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13954
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13971
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：13988
# 执行内存清理 - 批次 180
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14003
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14019
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14036
# 执行内存清理 - 批次 190
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14053
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14069
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14086
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14102
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14119
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14136
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14153
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14169
# 执行内存清理 - 批次 200
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14186
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14203
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14219
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14235
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14251
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14267
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14282
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14296
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14312
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14329
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14345
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14362
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14379
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14396
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14412
# Generated invalid data. Saved to 'invalid_outputs/6-软件与信息服务/软件外包及产业基地情况 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14429
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14445
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：14461
