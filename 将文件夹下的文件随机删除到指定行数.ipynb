# %%
import os
import pandas as pd
import random
import shutil

# %%
def process_csv_files(src_folder, dest_folder, min_rows):
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

    for root, dirs, files in os.walk(src_folder):
        # 计算目标路径中的相对路径
        relative_path = os.path.relpath(root, src_folder)
        dest_path = os.path.join(dest_folder, relative_path)

        # 创建目标路径中的子文件夹
        if not os.path.exists(dest_path):
            os.makedirs(dest_path)

        for file in files:
            if file.endswith('.csv'):
                src_file_path = os.path.join(root, file)
                dest_file_path = os.path.join(dest_path, file)

                try:
                    # 尝试读取CSV文件
                    df = pd.read_csv(src_file_path)
                    
                    # 随机删除行直到行数小于预定值
                    while len(df) > min_rows:
                        df = df.drop(random.choice(df.index))

                    # 保存处理后的CSV文件到目标文件夹
                    df.to_csv(dest_file_path, index=False)
                    
                    # 打印处理过的文件名
                    print(f"Processed file: {src_file_path}")
                
                except UnicodeDecodeError:
                    # 跳过无法读取的文件并打印文件名
                    print(f"Skipped file due to encoding error: {src_file_path}")

# %%
# 示例调用
src_folder = '经过第一遍处理之后的数据集'   # 将此处替换为你的大文件夹路径
dest_folder = '筛选出指定行之后的数据集' # 将此处替换为你希望保存的目标大文件夹路径
process_csv_files(src_folder, dest_folder, 10)  # 设置你期望的最小行数
# Out:
# Processed file: 经过第一遍处理之后的数据集\1-网络与通信\1-网络与通信 - OFDM跳频技术研究 (1).csv
# Processed file: 经过第一遍处理之后的数据集\1-网络与通信\1-网络与通信 - QoS（服务质量）技术研究 (1).csv
# Processed file: 经过第一遍处理之后的数据集\1-网络与通信\1-网络与通信 - 宽带网络基础结构 (1).csv
# Processed file: 经过第一遍处理之后的数据集\1-网络与通信\1-网络与通信 - 物联网各层级价值 (1).csv
# Processed file: 经过第一遍处理之后的数据集\1-网络与通信\1-网络与通信 - 网络与通信系统 (1).csv
# Processed file: 经过第一遍处理之后的数据集\1-网络与通信\1-网络与通信 - 蜂窝通信模块 (1).csv
# Processed file: 经过第一遍处理之后的数据集\10-智能机器人\10-智能机器人 - AGV智能机器人停车库应用 (1).csv
# Processed file: 经过第一遍处理之后的数据集\10-智能机器人\10-智能机器人 - 工业运动学机械手试验数据 (1).csv
# Processed file: 经过第一遍处理之后的数据集\10-智能机器人\10-智能机器人 - 智能机器人最大行进速度设定 (1).csv
# Processed file: 经过第一遍处理之后的数据集\10-智能机器人\10-智能机器人 - 智能机器人状态信息 (1).csv
# Processed file: 经过第一遍处理之后的数据集\10-智能机器人\10-智能机器人 - 智能机器人结构特点 (1).csv
# Processed file: 经过第一遍处理之后的数据集\10-智能机器人\10-智能机器人 - 智能机器人行进路径比较 (1).csv
# Processed file: 经过第一遍处理之后的数据集\10-智能机器人\10-智能机器人 - 核心技术 (1).csv
# Processed file: 经过第一遍处理之后的数据集\11-激光与增材制造\11-激光与增材制造 - 国内外MOPA脉冲光纤激光器规格参数 (1).csv
# Processed file: 经过第一遍处理之后的数据集\11-激光与增材制造\11-激光与增材制造 - 核心技术 (1).csv
# Processed file: 经过第一遍处理之后的数据集\11-激光与增材制造\11-激光与增材制造 - 核心零部件 (1).csv
# Processed file: 经过第一遍处理之后的数据集\11-激光与增材制造\11-激光与增材制造 - 激光器特性对比 (1).csv
# Processed file: 经过第一遍处理之后的数据集\12-精密仪器设备\12-精密仪器设备 - 压缩弹簧规格 (1).csv
# Processed file: 经过第一遍处理之后的数据集\12-精密仪器设备\12-精密仪器设备 - 器械技术水平 (1).csv
# Processed file: 经过第一遍处理之后的数据集\12-精密仪器设备\12-精密仪器设备 - 基准电源模块信息 (1).csv
# Processed file: 经过第一遍处理之后的数据集\12-精密仪器设备\12-精密仪器设备 - 核心技术 (1).csv
# Processed file: 经过第一遍处理之后的数据集\12-精密仪器设备\12-精密仪器设备 - 电阻测量仪技术规格 (1).csv
# Processed file: 经过第一遍处理之后的数据集\12-精密仪器设备\12-精密仪器设备 - 精密阻抗分析仪对比 (1).csv
# Processed file: 经过第一遍处理之后的数据集\13-新能源\13-新能源 - “一带一路”可再生能源发展研究 (2).csv
# Processed file: 经过第一遍处理之后的数据集\13-新能源\13-新能源 - 新能源电量库交易信息 (2).csv
# Processed file: 经过第一遍处理之后的数据集\13-新能源\13-新能源 - 新能源类别信息 (2).csv
# Processed file: 经过第一遍处理之后的数据集\13-新能源\13-新能源 - 有色金属材料组成 (2).csv
# Processed file: 经过第一遍处理之后的数据集\13-新能源\13-新能源 - 核心技术 (2).csv
# Processed file: 经过第一遍处理之后的数据集\13-新能源\13-新能源 - 装机规模发电量 (2).csv
# Processed file: 经过第一遍处理之后的数据集\14-安全节能环保\14-安全节能环保 - 企业业务考核体系设计.csv
# Processed file: 经过第一遍处理之后的数据集\14-安全节能环保\14-安全节能环保 - 安全应急信息化投入金额统计.csv
# Processed file: 经过第一遍处理之后的数据集\14-安全节能环保\14-安全节能环保 - 安全应急死亡人数数据统计.csv
# Processed file: 经过第一遍处理之后的数据集\14-安全节能环保\14-安全节能环保 - 应急能力评估体系.csv
# Processed file: 经过第一遍处理之后的数据集\14-安全节能环保\14-安全节能环保 - 节能环保企业名单.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 交通-公共交通情况实体属性.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 交通-国内主要城市地铁运营数据.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 交通-客运交通概况.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 交通-广东省城际客流总体分布.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 交通-枢纽口岸运行情况.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 交通-现状枢纽运营数据.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 交通-现状铁路运行数据.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 交通-道路交通情况.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 宏观基础-交通数据.csv
# Processed file: 经过第一遍处理之后的数据集\15-智能网联汽车\15-智能网联汽车 - 居民出行特征.csv
# Processed file: 经过第一遍处理之后的数据集\16-新材料\16-新材料 - 世界能源结构发展趋势.csv
# Processed file: 经过第一遍处理之后的数据集\16-新材料\16-新材料 - 世界锂资源产量预测.csv
# Processed file: 经过第一遍处理之后的数据集\16-新材料\16-新材料 - 城市资源消耗.csv
# Processed file: 经过第一遍处理之后的数据集\16-新材料\16-新材料 - 核心材料.csv
# Processed file: 经过第一遍处理之后的数据集\16-新材料\16-新材料 - 碳纤维主要应用产业.csv
# Processed file: 经过第一遍处理之后的数据集\16-新材料\16-新材料 - 能源消费.csv
# Processed file: 经过第一遍处理之后的数据集\16-新材料\16-新材料 - 锂电正极材料性能.csv
# Processed file: 经过第一遍处理之后的数据集\17-海洋\17-海洋 - 全国装机规模.csv
# Processed file: 经过第一遍处理之后的数据集\17-海洋\17-海洋 - 海上风电-历年全球海上风电装机规模及分布.csv
# Processed file: 经过第一遍处理之后的数据集\17-海洋\17-海洋 - 海上风电-海上风电施工船舶情况.csv
# Processed file: 经过第一遍处理之后的数据集\17-海洋\17-海洋 - 海工装备-船厂订单量.csv
# Processed file: 经过第一遍处理之后的数据集\17-海洋\17-海洋 - 海工装备制造-海工配套.csv
# Processed file: 经过第一遍处理之后的数据集\17-海洋\17-海洋 - 蛇口国际海洋-核心技术.csv
# Processed file: 经过第一遍处理之后的数据集\18-合成生物\18-合成生物 - 中国合成生物技术试验.csv
# Processed file: 经过第一遍处理之后的数据集\18-合成生物\18-合成生物 - 全球合成生物技术.csv
# Processed file: 经过第一遍处理之后的数据集\18-合成生物\18-合成生物 - 全球合成生物技术试验.csv
# Processed file: 经过第一遍处理之后的数据集\18-合成生物\18-合成生物 - 合成生物技术对生物多样性的潜在风险定性评估.csv
# Processed file: 经过第一遍处理之后的数据集\18-合成生物\18-合成生物 - 合成生物技术注册与受理库.csv
# Processed file: 经过第一遍处理之后的数据集\19-区块链\19-区块链 - 中国区块链技术系统试验.csv
# Processed file: 经过第一遍处理之后的数据集\19-区块链\19-区块链 - 区块链功能架构.csv
# Processed file: 经过第一遍处理之后的数据集\19-区块链\19-区块链 - 区块链技术系统.csv
# Processed file: 经过第一遍处理之后的数据集\19-区块链\19-区块链 - 区块链技术系统注册与受理库.csv
# Processed file: 经过第一遍处理之后的数据集\19-区块链\19-区块链 - 应用情况.csv
# Processed file: 经过第一遍处理之后的数据集\2-半导体与集成电路\2-半导体与集成电路 - Micro LED-关键事件节点 (1).csv
# Processed file: 经过第一遍处理之后的数据集\2-半导体与集成电路\2-半导体与集成电路 - Micro LED-核心技术 (1).csv
# Processed file: 经过第一遍处理之后的数据集\2-半导体与集成电路\2-半导体与集成电路 - 氮化镓-制造产线 (1).csv
# Processed file: 经过第一遍处理之后的数据集\2-半导体与集成电路\2-半导体与集成电路 - 集成电路-组成部件信息 (1).csv
# Processed file: 经过第一遍处理之后的数据集\20-细胞与基因\20-细胞与基因 - 国际食品安全指标.csv
# Processed file: 经过第一遍处理之后的数据集\20-细胞与基因\20-细胞与基因 - 细胞与基因-全球育种技术.csv
# Processed file: 经过第一遍处理之后的数据集\20-细胞与基因\20-细胞与基因 - 细胞与基因-核心技术.csv
# Processed file: 经过第一遍处理之后的数据集\20-细胞与基因\20-细胞与基因 - 细胞与基因（生物育种）-中国育种技术试验.csv
# Processed file: 经过第一遍处理之后的数据集\21-空天技术\21-空天技术 - 空天技术-技术注册与受理库.csv
# Processed file: 经过第一遍处理之后的数据集\21-空天技术\21-空天技术 - 空天技术-系统指标.csv
# Processed file: 经过第一遍处理之后的数据集\21-空天技术\21-空天技术 - 空天技术-系统试验.csv
# Processed file: 经过第一遍处理之后的数据集\21-空天技术\21-空天技术 - 空天技术-运营与维护.csv
# Processed file: 经过第一遍处理之后的数据集\21-空天技术\21-空天技术 - 空天技术系统设计.csv
# Processed file: 经过第一遍处理之后的数据集\22-脑科学与类脑智能\22-脑科学与类脑智能 - 中国上市人工智能系统.csv
# Processed file: 经过第一遍处理之后的数据集\22-脑科学与类脑智能\22-脑科学与类脑智能 - 人工智能--核心技术.csv
# Processed file: 经过第一遍处理之后的数据集\22-脑科学与类脑智能\22-脑科学与类脑智能 - 人工智能系统注册与受理库.csv
# Processed file: 经过第一遍处理之后的数据集\22-脑科学与类脑智能\22-脑科学与类脑智能 - 全球人工智能系统.csv
# Processed file: 经过第一遍处理之后的数据集\22-脑科学与类脑智能\22-脑科学与类脑智能 - 全球人工智能系统试验.csv
# Processed file: 经过第一遍处理之后的数据集\23-深地深海\23-深地深海 - 海洋产业链--保险信息库.csv
# Processed file: 经过第一遍处理之后的数据集\23-深地深海\23-深地深海 - 海洋产业链--信贷银行.csv
# Processed file: 经过第一遍处理之后的数据集\23-深地深海\23-深地深海 - 海洋产业链--基金信息.csv
# Processed file: 经过第一遍处理之后的数据集\23-深地深海\23-深地深海 - 海洋科技--空间图谱.csv
# Processed file: 经过第一遍处理之后的数据集\24-可见光通信与光计算\24-可见光通信与光计算 - 中国上市可见光通信与光计算系统.csv
# Processed file: 经过第一遍处理之后的数据集\24-可见光通信与光计算\24-可见光通信与光计算 - 可见光通信与光计算系统.csv
# Processed file: 经过第一遍处理之后的数据集\24-可见光通信与光计算\24-可见光通信与光计算 - 可见光通信与光计算系统注册与受理库.csv
# Processed file: 经过第一遍处理之后的数据集\24-可见光通信与光计算\24-可见光通信与光计算 - 可见光通信与光计算系统试验.csv
# Processed file: 经过第一遍处理之后的数据集\24-可见光通信与光计算\24-可见光通信与光计算 - 正交频分复用（OFDM）调制技术.csv
# Processed file: 经过第一遍处理之后的数据集\25-量子信息\25-量子信息 - 潜在应用场景分析报告.csv
# Processed file: 经过第一遍处理之后的数据集\25-量子信息\25-量子信息 - 量子信息—成果应用.csv
# Processed file: 经过第一遍处理之后的数据集\25-量子信息\25-量子信息 - 量子信息—评价情况.csv
# Processed file: 经过第一遍处理之后的数据集\25-量子信息\25-量子信息 - 量子计算--物理实现.csv
# Processed file: 经过第一遍处理之后的数据集\3-超高清视频显示\3-超高清视频显示 - 8K超高清视频相关技术 (1).csv
# Processed file: 经过第一遍处理之后的数据集\3-超高清视频显示\3-超高清视频显示 - LED液晶显示屏相关技术 (1).csv
# Processed file: 经过第一遍处理之后的数据集\3-超高清视频显示\3-超高清视频显示 - 数字视频标准 (1).csv
# Processed file: 经过第一遍处理之后的数据集\3-超高清视频显示\3-超高清视频显示 - 硬件系统 (1).csv
# Processed file: 经过第一遍处理之后的数据集\3-超高清视频显示\3-超高清视频显示 - 系统相关参数 (1).csv
# Processed file: 经过第一遍处理之后的数据集\3-超高清视频显示\3-超高清视频显示 - 软件系统 (1).csv
# Processed file: 经过第一遍处理之后的数据集\4-智能终端\4-智能终端 - 家庭智能终端基本信息 (1).csv
# Processed file: 经过第一遍处理之后的数据集\4-智能终端\4-智能终端 - 移动芯片 (1).csv
# Processed file: 经过第一遍处理之后的数据集\4-智能终端\4-智能终端 - 终端载体情况 (1).csv
# Processed file: 经过第一遍处理之后的数据集\4-智能终端\4-智能终端 - 适老化智能终端基本信息 (1).csv
# Processed file: 经过第一遍处理之后的数据集\4-智能终端\4-智能终端 - 零部件信息 (1).csv
# Processed file: 经过第一遍处理之后的数据集\5-智能传感器\5-智能传感器 - HART通信协议 (1).csv
# Processed file: 经过第一遍处理之后的数据集\5-智能传感器\5-智能传感器 - 传感器属性 (1).csv
# Processed file: 经过第一遍处理之后的数据集\5-智能传感器\5-智能传感器 - 传感器系统 (1).csv
# Processed file: 经过第一遍处理之后的数据集\5-智能传感器\5-智能传感器 - 品类细分研究 (1).csv
# Processed file: 经过第一遍处理之后的数据集\5-智能传感器\5-智能传感器 - 基础结构组成 (1).csv
# Processed file: 经过第一遍处理之后的数据集\6-软件与信息服务\6-软件与信息服务 - MES应用信息 (1).csv
# Processed file: 经过第一遍处理之后的数据集\6-软件与信息服务\6-软件与信息服务 - 数字内容供应 (1).csv
# Processed file: 经过第一遍处理之后的数据集\6-软件与信息服务\6-软件与信息服务 - 软件与信息技术服务商主要核心技术 (1).csv
# Processed file: 经过第一遍处理之后的数据集\6-软件与信息服务\6-软件与信息服务 - 软件与信息技术服务商咨询与解决方案案例 (1).csv
# Processed file: 经过第一遍处理之后的数据集\6-软件与信息服务\6-软件与信息服务 - 软件外包及产业基地情况 (1).csv
# Processed file: 经过第一遍处理之后的数据集\7-数字创意\7-数字创意 - 剧集播放排行表 (1).csv
# Processed file: 经过第一遍处理之后的数据集\7-数字创意\7-数字创意 - 动画主题词及评论 (1).csv
# Processed file: 经过第一遍处理之后的数据集\7-数字创意\7-数字创意 - 数字创意产业细分领域用户规模.csv
# Processed file: 经过第一遍处理之后的数据集\7-数字创意\7-数字创意 - 视频平台剧集播放统计 (1).csv
# Processed file: 经过第一遍处理之后的数据集\8-现代时尚\8-现代时尚 - 健身人数信息 (3).csv
# Processed file: 经过第一遍处理之后的数据集\8-现代时尚\8-现代时尚 - 各运动品牌技术水平 (1).csv
# Processed file: 经过第一遍处理之后的数据集\8-现代时尚\8-现代时尚 - 服装企业渠道分析 (1).csv
# Processed file: 经过第一遍处理之后的数据集\8-现代时尚\8-现代时尚 - 面料科技含量 (1).csv
# Processed file: 经过第一遍处理之后的数据集\9-工业母机\9-工业母机 - 关键零部件供给信息 (1).csv
# Processed file: 经过第一遍处理之后的数据集\9-工业母机\9-工业母机 - 数控机床特有字段名称信息 (1).csv
# Processed file: 经过第一遍处理之后的数据集\9-工业母机\9-工业母机 - 普通金属切削机床数控化加工工艺 (1).csv
# Processed file: 经过第一遍处理之后的数据集\9-工业母机\9-工业母机 - 核心技术 (1).csv
# Processed file: 经过第一遍处理之后的数据集\9-工业母机\9-工业母机 - 超精密机床技术参数 (1).csv
# Processed file: 经过第一遍处理之后的数据集\9-工业母机\9-工业母机 - 金属切割机床评价指标 (1).csv
