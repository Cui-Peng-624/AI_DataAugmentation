# %%
from 整合版本1014 import main

# %%
import re

def extract_categories(filename):
    # 使用正则表达式匹配文件名格式
    match = re.match(r'(\d+-.+?) - (.+)', filename)
    if match:
        main_category = match.group(1).strip()
        sub_category = match.group(2).strip()
        return main_category, sub_category
    else:
        return None, None

# %%
# 示例调用
if __name__ == "__main__":
    file_names = ["7-数字创意 - 动画主题词及评论 (1)", "7-数字创意 - 剧集播放排行表 (1)", "7-数字创意 - 视频平台剧集播放统计 (1)", "7-数字创意 - 数字创意产业细分领域用户规模"] # 不需要带“.csv”后缀

    for file_name in file_names:
        main_category, sub_category = extract_categories(file_name)
        file_path = f"筛选出指定行之后的数据集/{main_category}/{file_name}.csv"
        save_path = f"1029扩充后的数据集/{main_category}/{file_name}_expanded.csv"
        save_invalid_path = f"invalid_outputs/{main_category}/{sub_category}.txt"

        num_entries = 20
        custom_requirements = ""
        required_total_rows = 20000

        # 执行主流程
        main(file_path, save_path, main_category, sub_category, num_entries, custom_requirements, required_total_rows, save_invalid_path)
# Out:
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15161
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15179
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15196
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15214
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15232
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15248
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15265
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15283
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15299
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15316
# 执行内存清理 - 批次 10
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15334
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15352
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15370
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15388
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15406
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15423
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15440
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15457
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15475
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15492
# 执行内存清理 - 批次 20
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15510
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15528
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15545
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15562
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15578
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15596
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15614
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15632
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15649
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15667
# 执行内存清理 - 批次 30
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15685
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15703
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15720
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15738
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15755
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15773
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15790
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15807
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15825
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15843
# 执行内存清理 - 批次 40
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15860
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15877
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15894
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15911
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15928
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15946
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15962
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15980
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：15998
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16015
# 执行内存清理 - 批次 50
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16032
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16049
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16066
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16084
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16101
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16118
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16136
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16154
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16172
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16189
# 执行内存清理 - 批次 60
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16207
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16224
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16241
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16258
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16276
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16294
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16311
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16328
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16346
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16364
# 执行内存清理 - 批次 70
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16382
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16400
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16417
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16435
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16452
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16469
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16487
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16504
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16521
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16539
# 执行内存清理 - 批次 80
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16556
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16573
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16591
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16607
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16624
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16642
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16659
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16676
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16693
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16711
# 执行内存清理 - 批次 90
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16729
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16746
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16764
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16782
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16799
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16817
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16835
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16852
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16869
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16886
# 执行内存清理 - 批次 100
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16903
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16922
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16939
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16956
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16974
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：16991
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17008
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17026
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17044
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17063
# 执行内存清理 - 批次 110
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17080
# Generated invalid data. Saved to 'invalid_outputs/7-数字创意/动画主题词及评论 (1).txt' for manual processing.
# 发生错误：cannot access local variable 'generated_data' where it is not associated with a value。继续下一次生成。
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17098
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17116
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17134
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17151
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17169
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17187
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17205
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17222
# 执行内存清理 - 批次 120
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17240
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17256
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17273
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17290
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17308
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17326
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17343
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17360
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17378
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17396
# 执行内存清理 - 批次 130
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17413
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17431
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17449
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17467
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17484
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17501
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17519
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17536
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17554
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17571
# 执行内存清理 - 批次 140
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17588
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17605
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17623
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17641
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17658
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17676
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17693
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17710
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17727
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17744
# 执行内存清理 - 批次 150
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17762
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17779
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17798
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17816
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17833
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17850
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17867
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17885
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17902
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17920
# 执行内存清理 - 批次 160
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17937
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17955
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17973
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：17990
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18009
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18027
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18044
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18062
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18079
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18098
# 执行内存清理 - 批次 170
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18115
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18133
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18151
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18168
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18186
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18203
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18220
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18238
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18256
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18273
# 执行内存清理 - 批次 180
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18290
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18308
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18326
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18344
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18361
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18379
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18397
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18415
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18433
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18449
# 执行内存清理 - 批次 190
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18467
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18484
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18501
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18516
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18533
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18551
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18569
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18586
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18603
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18621
# 执行内存清理 - 批次 200
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18639
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18657
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18675
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18693
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18710
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18727
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18745
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18763
# Generated valid data.
# 已生成数据并追加到文件。当前总行数：18780
